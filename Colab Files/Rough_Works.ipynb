# %% [markdown]
# <a href="https://colab.research.google.com/github/tripathishubham1/Travel-Hostel-Startup---Market-Segmentation/blob/main/Colab%20Files/Rough_Works.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Rough Works

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import numpy as np 
import os 
import pandas as pd

# %%
df = pd.read_csv('/content/Tourism_In_India_Statistics_2018-Table_5 - Tourism_In_India_Statistics_2018-Table_5 (1).csv')

# %%
df
# Out:
#              State  ... Foreign Percentage growth - 2017-18/2016-17
# 0    Uttar Pradesh  ...                                        18.9
# 1    Uttar Pradesh  ...                                        11.0
# 2    Uttar Pradesh  ...                                         5.6
# 3    Uttar Pradesh  ...                                       138.8
# 4    Uttar Pradesh  ...                                       -40.7
# ..             ...  ...                                         ...
# 111        Gujarat  ...                                        51.6
# 112        Gujarat  ...                                        62.7
# 113        Gujarat  ...                                        68.2
# 114        Gujarat  ...                                        56.1
# 115        Gujarat  ...                                      -100.0
#
# [116 rows x 11 columns]

# %%
df_Agra
# Out:
#            State  ... Foreign Percentage growth - 2017-18/2016-17
# 0  Uttar Pradesh  ...                                        18.9
# 1  Uttar Pradesh  ...                                        11.0
# 2  Uttar Pradesh  ...                                         5.6
# 3  Uttar Pradesh  ...                                       138.8
# 4  Uttar Pradesh  ...                                       -40.7
# 5  Uttar Pradesh  ...                                        72.4
# 6  Uttar Pradesh  ...                                       606.1
# 7  Uttar Pradesh  ...                                      6256.2
#
# [8 rows x 11 columns]

# %%
df_Agra.plot(x="State", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_Tamilnadu = df.groupby(df.State)
df_Tamilnadu = df_Tamilnadu.get_group('Tamilnadu')
df_Tamilnadu.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_up = df.groupby(df.State)
df_up = df_up.get_group('Uttar Pradesh')
df_up.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_kt = df.groupby(df.State)
df_kt = df_kt.get_group('Karnataka')
df_kt.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_mh = df.groupby(df.State)
df_mh = df_mh.get_group('Maharashtra')
df_mh.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_mp = df.groupby(df.State)
df_mp = df_mp.get_group('Madhya Pradesh')
df_mp.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_wb = df.groupby(df.State)
df_wb = df_wb.get_group('West Bengal')
df_wb.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df_gj = df.groupby(df.State)
df_gj = df_gj.get_group('Gujarat')
df_gj.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_rj = df.groupby(df.State)
df_rj = df_rj.get_group('Rajasthan')
df_rj.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_pb = df.groupby(df.State)
df_pb = df_pb.get_group('Punjab')
df_pb.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_bh = df.groupby(df.State)
df_bh = df_bh.get_group('Bihar')
df_bh.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_Chennai = df.groupby(df.Circle)
df_Chennai = df_Chennai.get_group('Chennai Circle')
df_Chennai.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_Chennai = df.groupby(df.Circle)
df_Chennai = df_Chennai.get_group('Chennai Circle')
df_Chennai.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df_Agra.plot(x="Name of the Monument", y=["Domestic - 2016-17","Foreign - 2016-17","Domestic - 2017-18","Foreign - 2017-18"], kind="bar",figsize=(10,5))

# %%
df = df.drop(labels=['Railway(in km)'],axis=1)

# %%
def plotScatterMatrix(df,)
# Out:
#   File "<ipython-input-29-0f77f2346fb5>", line 1
#     def plotScatterMatrix(df,116,10)
#                                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Tourism_In_India_Statistics_2018-Table_5 - Tourism_In_India_Statistics_2018-Table_5.csv')

# %%
df1 = pd.read_csv('/content/RS-Session-251-AU1434-Table1.csv')

# %%
df1
# Out:
#                    States/UTs       2014  ...       2017  2018 (Revised)
# 0   Andaman & Nicobar Islands     285146  ...     471919          498279
# 1              Andhra Pradesh   93306974  ...  165433898       194767874
# 2           Arunachal Pradesh     335974  ...     444005          512436
# 3                       Assam    4826702  ...    6052667         5856282
# 4                       Bihar   22544377  ...   32414063        33621613
# 5                  Chandigarh    1061419  ...    1425781         1538796
# 6                Chhattisgarh   24488465  ...   17350030        19329501
# 7        Dadra & Nagar Haveli     579638  ...     614182          609435
# 8                 Daman & Diu     795167  ...     858131          898824
# 9                     Delhi *   22626859  ...   29114423        29114423
# 10                        Goa    3544634  ...    6895234         7081559
# 11                    Gujarat   30912043  ...   48343121        54369873
# ...

# %%
x = range(35)

new = plt.bar(x,df1['2014'])
plt.ylabel('No of Visitors In Years')
plt.xticks(x,df1['States/UTs'],rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-e9ed0eb24faf> in <module>()
#       1 x = range(35)
#       2
# ----> 3 new = plt.bar(x,df1['2014'])
#       4 plt.ylabel('No of Visitors In Years')
#       5 plt.xticks(x,df1['States/UTs'],rotation='vertical')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %%
df1.plot(x="States/UTs", y=["2016","2017","2018 (Revised)"], kind="bar",figsize=(20,10))

# %%
plt.style.use('fivethirtyseven')
plt.figure(figsize=(20,20))
plt.title("Neighbourhood Group")
g = plt.pie(df1['2016'], labels=df1['States/UTs'].value_counts().index,autopct='%1.1f%%', startangle=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/matplotlib/style/core.py in use(style)
#     113             try:
# --> 114                 rc = rc_params_from_file(style, use_default_template=False)
#     115                 _apply_style(rc)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#     983     """
# --> 984     config_from_file = _rc_params_in_file(fname, fail_on_error)
#     985
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in _rc_params_in_file(fname, fail_on_error)
#     913     rc_temp = {}
# --> 914     with _open_file_or_url(fname) as fd:
#     915         try:
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     111         try:
# --> 112             return next(self.gen)
# ...

# %%
df
# Out:
#              State  ... Foreign Percentage growth - 2017-18/2016-17
# 0    Uttar Pradesh  ...                                        18.9
# 1    Uttar Pradesh  ...                                        11.0
# 2    Uttar Pradesh  ...                                         5.6
# 3    Uttar Pradesh  ...                                       138.8
# 4    Uttar Pradesh  ...                                       -40.7
# ..             ...  ...                                         ...
# 111        Gujarat  ...                                        51.6
# 112        Gujarat  ...                                        62.7
# 113        Gujarat  ...                                        68.2
# 114        Gujarat  ...                                        56.1
# 115        Gujarat  ...                                      -100.0
#
# [116 rows x 11 columns]

# %%
def mean(dff,c):
  sum = 0
  for i in dff[c]:
    sum = sum + i
  
  m = sum/len(dff[c])
  return m




new_df = pd.DataFrame(columns=['Circle','Domestic 2016-17 Mean','Domestic 2017-18 Mean','Foreign 2016-17 Mean','Foreign 2017-18 Mean'])

# %%
agra_mean
# Out:
# 1059302.25

# %%
# perform groupby
res = df.groupby('Circle')[['Domestic - 2016-17', 'Foreign - 2016-17','Domestic - 2017-18','Foreign - 2017-18']].sum().reset_index()

print(res)
# Out:
#                 Circle  ...  Foreign - 2017-18
# 0          Agra Circle  ...            1780935
# 1    Aurangabad Circle  ...             106986
# 2     Bengaluru Circle  ...              62335
# 3        Bhopal Circle  ...             115208
# 4   Bhubaneswar Circle  ...              14652
# 5    Chandigarh Circle  ...                272
# 6       Chennai Circle  ...             105959
# 7         Delhi Circle  ...             700860
# 8       Dharwad Circle  ...              25214
# 9      Guwahati Circle  ...               2734
# 10   Hampi Mini Circle  ...              54446
# 11    Hyderabad Circle  ...              47404
# 12       Jaipur Circle  ...               7779
# 13      Jodhpur Circle  ...              42803
# 14      Kolkata Circle  ...               3523
# 15     Leh Mini Circle  ...               7549
# 16      Lucknow Circle  ...              32817
# 17       Mumbai Circle  ...              94701
# 18        Patna Circle  ...              58416
# ...

# %%
res
# Out:
#                 Circle  ...  Foreign - 2017-18
# 0          Agra Circle  ...            1780935
# 1    Aurangabad Circle  ...             106986
# 2     Bengaluru Circle  ...              62335
# 3        Bhopal Circle  ...             115208
# 4   Bhubaneswar Circle  ...              14652
# 5    Chandigarh Circle  ...                272
# 6       Chennai Circle  ...             105959
# 7         Delhi Circle  ...             700860
# 8       Dharwad Circle  ...              25214
# 9      Guwahati Circle  ...               2734
# 10   Hampi Mini Circle  ...              54446
# 11    Hyderabad Circle  ...              47404
# 12       Jaipur Circle  ...               7779
# 13      Jodhpur Circle  ...              42803
# 14      Kolkata Circle  ...               3523
# 15     Leh Mini Circle  ...               7549
# 16      Lucknow Circle  ...              32817
# 17       Mumbai Circle  ...              94701
# 18        Patna Circle  ...              58416
# ...

# %%
res.plot(x="Circle", y=['Domestic - 2016-17','Foreign - 2016-17','Domestic - 2017-18','Foreign - 2017-18'], kind="bar",figsize=(20,10))

# %%
res1 = df.groupby('State')[['Domestic - 2016-17', 'Foreign - 2016-17','Domestic - 2017-18','Foreign - 2017-18']].sum().reset_index()
res1
# Out:
#                State  Domestic - 2016-17  ...  Domestic - 2017-18  Foreign - 2017-18
# 0              Assam              392967  ...              631139               2734
# 1              Bihar             1246998  ...             1399719              58416
# 2        Chattisgadh               52559  ...               91602                 72
# 3            Gujarat              806483  ...              873690              15472
# 4   Himachal Pradesh              187361  ...              252019               6103
# 5    Jammu & Kashmir               72112  ...               89731              22603
# 6          Karnataka             4338413  ...             5582747             141995
# 7             Kerala              716298  ...              934953             122542
# 8     Madhya Pradesh             1713459  ...             2323995             115208
# 9        Maharashtra             6862070  ...             8998192             201687
# ...

# %%
res1.plot(x="State", y=['Domestic - 2016-17','Foreign - 2016-17','Domestic - 2017-18','Foreign - 2017-18'], kind="bar",figsize=(20,10))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
res
# Out:
#                 Circle  ...  Foreign - 2017-18
# 0          Agra Circle  ...            1780935
# 1    Aurangabad Circle  ...             106986
# 2     Bengaluru Circle  ...              62335
# 3        Bhopal Circle  ...             115208
# 4   Bhubaneswar Circle  ...              14652
# 5    Chandigarh Circle  ...                272
# 6       Chennai Circle  ...             105959
# 7         Delhi Circle  ...             700860
# 8       Dharwad Circle  ...              25214
# 9      Guwahati Circle  ...               2734
# 10   Hampi Mini Circle  ...              54446
# 11    Hyderabad Circle  ...              47404
# 12       Jaipur Circle  ...               7779
# 13      Jodhpur Circle  ...              42803
# 14      Kolkata Circle  ...               3523
# 15     Leh Mini Circle  ...               7549
# 16      Lucknow Circle  ...              32817
# 17       Mumbai Circle  ...              94701
# 18        Patna Circle  ...              58416
# ...

# %%
res.shape
# Out:
# (25, 5)

# %%
res.describe()
# Out:
#        Domestic - 2016-17  ...  Foreign - 2017-18
# count        2.500000e+01  ...       2.500000e+01
# mean         1.803068e+06  ...       1.452247e+05
# std          2.305899e+06  ...       3.682887e+05
# min          3.469900e+04  ...       7.200000e+01
# 25%          3.929670e+05  ...       7.779000e+03
# 50%          9.355780e+05  ...       4.280300e+04
# 75%          2.126087e+06  ...       1.059590e+05
# max          8.626644e+06  ...       1.780935e+06
#
# [8 rows x 4 columns]

# %%
res.dtypes
# Out:
# Circle                object
# Domestic - 2016-17     int64
# Foreign - 2016-17      int64
# Domestic - 2017-18     int64
# Foreign - 2017-18      int64
# dtype: object

# %%
res.isnull().sum()
# Out:
# Circle                0
# Domestic - 2016-17    0
# Foreign - 2016-17     0
# Domestic - 2017-18    0
# Foreign - 2017-18     0
# dtype: int64

# %%
plt.figure(1, figsize=(30,5))
n = 0
for x in ['Domestic - 2016-17','Foreign - 2016-17','Domestic - 2017-18','Foreign - 2017-18']:
  n += 1
  plt.subplot(1,4,n)
  plt.subplots_adjust(hspace = 2.5 , wspace = 0.5)
  sns.distplot(res[x],bins = 20)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(15,10))
sns.countplot(y='Circle',data=df)
plt.title('No of Tourism Places Counts (City Wise)')
plt.show()

# %%
plt.figure(1, figsize=(30,5))
n = 0
for x in ['Domestic - 2016-17','Foreign - 2016-17','Domestic - 2017-18','Foreign - 2017-18']:
  n += 1
  plt.subplot(1,4,n)
  plt.subplots_adjust(hspace = 2.5 , wspace = 0.5)
  sns.boxplot(res[x])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(df.corr(),annot=True)
ax.set_title('Visulaization')
# Out:
# Text(0.5, 1.0, 'Visulaization')

# %%
df.plot(x="Name of the Monument", y=['Railway','Airport'], kind="bar",figsize=(30,5))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(1, figsize=(30,5))
n = 0
for x in ['Airport','Railway']:
  n += 1
  plt.subplot(1,4,n)
  plt.subplots_adjust(hspace = 2.5 , wspace = 0.5)
  sns.distplot(df[x],bins = 20)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for i in ['Domestic - 2016-17','Foreign - 2016-17','Domestic - 2017-18','Foreign - 2017-18','Airport','Railway']:
    sns.histplot(x=df[i],kde=True)
    plt.xlabel(i)
    plt.show()
